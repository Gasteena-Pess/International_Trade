# %% [markdown]
# # STEP 1 : BUSINESS UNDERSTANDING

# %% [markdown]
# The dataset represents historical trade data (exports, imports, trade balance) over a span of years. A
#
# Trade Balance: This indicates if the country is exporting more than importing (surplus) or the reverse (deficit).
#
# Exports vs Imports: To evaluate the country's international market performance.
#
# Goods vs Services: To understand the relative contribution of goods and services in the overall trade.

# %% [markdown]
# # STEP 2 : DOMAIN KNOWLEDGE

# %% [markdown]
# ### Key Columns:
# Period: Likely the time (e.g., year, month, or quarter) during which the trade data was recorded.
#
# Balance Total: The total trade balance, which is the difference between total exports and imports. A positive balance indicates a trade surplus, while a negative balance indicates a deficit.
#
# Balance Goods BOP: Trade balance specifically for goods, based on the Balance of Payments (BOP) system.
#
# Balance Services: Trade balance specifically for services.
#
# Exports Total: Total exports, including both goods and services.
#
# Exports Goods BOP: Exports of goods only, based on the BOP system.
#
# Exports Services: Exports of services.
#
# Imports Total: Total imports, including both goods and services.
#
# Imports Goods BOP: Imports of goods only, based on the BOP system.
#
# Imports Services: Imports of services.

# %% [markdown]
# ### Why is it important?
# Economic Health Indicator: Trade data serves as a crucial indicator of a country’s economic health. A positive trade balance (more exports than imports) can indicate economic strength, while a negative balance may suggest economic vulnerabilities.
#
# Policy Formulation: Understanding trade patterns assists policymakers in developing effective trade policies. It helps in analyzing the impacts of tariffs, trade agreements, and international relationships.
#
# Market Competitiveness: Businesses and analysts can assess the U.S. competitiveness in global markets by evaluating export and import trends. This data can inform strategic decisions for businesses looking to expand internationally or adjust to changing market conditions.
#
# Investment Decisions: Investors often look at trade balances and trends to gauge market potential and make informed investment decisions in sectors affected by international trade.
#
# Global Supply Chain Insights: The dataset can provide insights into supply chain dynamics, helping businesses and governments understand dependencies on foreign goods and services.
#
# Trend Analysis: Historical trade data allows for trend analysis over time, facilitating long-term economic forecasts and strategic planning.

# %%
import pandas as pd

# %%
# Load the dataset
data_path = '/Users/gasteenapess/Shipment_Trading/gands.csv'
df = pd.read_csv(data_path)

# %%
#Basic Exploration
print("Dataset Shape:", df.shape) 
print("\nColumns in the dataset:", df.columns.tolist())  
print("\nFirst 5 rows of the dataset:\n", df.head())  
print("\nData Types:\n", df.dtypes)  
print("\nLast 5 rows of the dataset:\n", df.tail())
# Out:
# Dataset Shape: (107, 10)
#
# Columns in the dataset: ['Period', 'Balance Total', 'Balance Goods BOP', 'Balance Services', 'Exports Total', 'Exports Goods BOP', 'Exports Services', 'Imports Total ', 'Imports Goods BOP', 'Imports Services']
#
# First 5 rows of the dataset:
#     Period Balance Total Balance Goods BOP Balance Services Exports Total  \
# 0  1960.0         3,508             4,892           -1,384        25,940
# 1  1961.0         4,195             5,571           -1,376        26,403
# 2  1962.0         3,370             4,521           -1,151        27,722
# 3  1963.0         4,210             5,224           -1,014        29,620
# 4  1964.0         6,022             6,801             -779        33,341
#
#   Exports Goods BOP Exports Services Imports Total  Imports Goods BOP  \
# 0            19,650            6,290         22,432            14,758
# 1            20,108            6,295         22,208            14,537
# ...

# %%
# Basic Statistical Summary
print("\nStatistical Summary:\n", df.describe())
# Out:
# Statistical Summary:
#              Period
# count    56.000000
# mean   1987.500000
# std      16.309506
# min    1960.000000
# 25%    1973.750000
# 50%    1987.500000
# 75%    2001.250000
# max    2015.000000

# %%
print("Dataset Structure:\n")
print(df.info())
# Out:
# Dataset Structure:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Period             56 non-null     float64
#  1   Balance Total      56 non-null     object
#  2   Balance Goods BOP  56 non-null     object
#  3   Balance Services   56 non-null     object
#  4   Exports Total      56 non-null     object
#  5   Exports Goods BOP  56 non-null     object
#  6   Exports Services   56 non-null     object
#  7   Imports Total      56 non-null     object
#  8   Imports Goods BOP  56 non-null     object
#  9   Imports Services   56 non-null     object
# dtypes: float64(1), object(9)
# memory usage: 8.5+ KB
# None

# %%
# List of columns 
print("\nList of Columns:\n")
print(df.columns)
# Out:
# List of Columns:
#
# Index(['Period', 'Balance Total', 'Balance Goods BOP', 'Balance Services',
#        'Exports Total', 'Exports Goods BOP', 'Exports Services',
#        'Imports Total ', 'Imports Goods BOP', 'Imports Services'],
#       dtype='object')

# %%
#  Basic statistics summary of the dataset 
print("\nStatistical Summary of the dataset:\n")
print(df.describe(include='all'))
# Out:
# Statistical Summary of the dataset:
#
#              Period Balance Total Balance Goods BOP Balance Services  \
# count     56.000000            56                56               56
# unique          NaN            56                56               56
# top             NaN         3,508             4,892           -1,384
# freq            NaN             1                 1                1
# mean    1987.500000           NaN               NaN              NaN
# std       16.309506           NaN               NaN              NaN
# min     1960.000000           NaN               NaN              NaN
# 25%     1973.750000           NaN               NaN              NaN
# 50%     1987.500000           NaN               NaN              NaN
# 75%     2001.250000           NaN               NaN              NaN
# max     2015.000000           NaN               NaN              NaN
#
#        Exports Total Exports Goods BOP Exports Services Imports Total   \
# ...

# %% [markdown]
# # STEP 3 : DATA CLEANING

# %%
# Handle Missing Values
print("\nMissing Values in each column:\n", df.isnull().sum())

# Dropping rows with all missing values
df.dropna(how='all', inplace=True)
# Out:
# Missing Values in each column:
#  Period               51
# Balance Total        51
# Balance Goods BOP    51
# Balance Services     51
# Exports Total        51
# Exports Goods BOP    51
# Exports Services     51
# Imports Total        51
# Imports Goods BOP    51
# Imports Services     51
# dtype: int64

# %%
print("\nNumber of duplicate rows:", df.duplicated().sum())
df.drop_duplicates(inplace=True)
# Out:
# Number of duplicate rows: 0

# %%
for column in df.columns:
    print(f"{column} unique values: {df[column].unique()}")
# Out:
# Period unique values: [1960. 1961. 1962. 1963. 1964. 1965. 1966. 1967. 1968. 1969. 1970. 1971.
#  1972. 1973. 1974. 1975. 1976. 1977. 1978. 1979. 1980. 1981. 1982. 1983.
#  1984. 1985. 1986. 1987. 1988. 1989. 1990. 1991. 1992. 1993. 1994. 1995.
#  1996. 1997. 1998. 1999. 2000. 2001. 2002. 2003. 2004. 2005. 2006. 2007.
#  2008. 2009. 2010. 2011. 2012. 2013. 2014. 2015.]
# Balance Total unique values: ['3,508' '4,195' '3,370' '4,210' '6,022' '4,664' '2,939' '2,604' '250'
#  '91' '2,254' '-1,302' '-5,443' '1,900' '-4,293' '12,404' '-6,082'
#  '-27,246' '-29,763' '-24,565' '-19,407' '-16,172' '-24,156' '-57,767'
#  '-1,09,072' '-1,21,880' '-1,38,538' '-1,51,684' '-1,14,566' '-93,141'
#  '-80,864' '-31,135' '-39,212' '-70,311' '-98,493' '-96,384' '-1,04,065'
#  '-1,08,273' '-1,66,140' '-2,58,617' '-3,72,517' '-3,61,511' '-4,18,955'
#  '-4,93,890' '-6,09,883' '-7,14,245' '-7,61,716' '-7,05,375' '-7,08,726'
#  '-3,83,774' '-4,94,658' '-5,48,625' '-5,36,773' '-4,61,876' '-4,90,176'
# ...

# %%
df.columns = df.columns.str.strip()
# Convert 'Period' to datetime
df['Period'] = pd.to_datetime(df['Period'], errors='coerce')

# Convert relevant object columns to numeric
numeric_columns = [
    'Balance Total',
    'Balance Goods BOP',
    'Balance Services',
    'Exports Total',
    'Exports Goods BOP',
    'Exports Services',
    'Imports Total',
    'Imports Goods BOP',
    'Imports Services'
]

for col in numeric_columns:
    df[col] = pd.to_numeric(df[col].astype(str).str.replace(',', '').replace('nan', '0'), errors='coerce')

print("\nUpdated Data Types:")
print(df.dtypes)

print("\nUpdated DataFrame:")
print(df.head())
# Out:
# Updated Data Types:
# Period               datetime64[ns]
# Balance Total                 int64
# Balance Goods BOP             int64
# Balance Services              int64
# Exports Total                 int64
# Exports Goods BOP             int64
# Exports Services              int64
# Imports Total                 int64
# Imports Goods BOP             int64
# Imports Services              int64
# dtype: object
#
# Updated DataFrame:
#                          Period  Balance Total  Balance Goods BOP  \
# 0 1970-01-01 00:00:00.000001960           3508               4892
# 1 1970-01-01 00:00:00.000001961           4195               5571
# 2 1970-01-01 00:00:00.000001962           3370               4521
# 3 1970-01-01 00:00:00.000001963           4210               5224
# 4 1970-01-01 00:00:00.000001964           6022               6801
#
#    Balance Services  Exports Total  Exports Goods BOP  Exports Services  \
# ...

# %%
#  Basic statistics summary of the dataset 
print("\nStatistical Summary of the dataset:\n")
print(df.describe(include='all'))
# Out:
# Statistical Summary of the dataset:
#
#                               Period  Balance Total  Balance Goods BOP  \
# count                             56      56.000000          56.000000
# mean   1970-01-01 00:00:00.000001987 -187736.089286     -239605.892857
# min    1970-01-01 00:00:00.000001960 -761716.000000     -837289.000000
# 25%    1970-01-01 00:00:00.000001973 -375331.250000     -453898.500000
# 50%    1970-01-01 00:00:00.000001987  -87002.500000     -115120.500000
# 75%    1970-01-01 00:00:00.000002001   -3545.250000       -4693.750000
# max    1970-01-01 00:00:00.000002015   12404.000000        8903.000000
# std                              NaN  237806.243190      292109.320309
#
#        Balance Services  Exports Total  Exports Goods BOP  Exports Services  \
# count         56.000000   5.600000e+01       5.600000e+01         56.000000
# mean       51869.732143   6.892564e+05       4.909360e+05     198320.446429
# ...

# %% [markdown]
# # STEP 4 : DATA ANALYSIS & STEP 5 : DATA VISUALIZING

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Descriptive Statistics
print("Descriptive Statistics:")
print(df.describe())
# Out:
# Descriptive Statistics:
#                               Period  Balance Total  Balance Goods BOP  \
# count                             56      56.000000          56.000000
# mean   1970-01-01 00:00:00.000001987 -187736.089286     -239605.892857
# min    1970-01-01 00:00:00.000001960 -761716.000000     -837289.000000
# 25%    1970-01-01 00:00:00.000001973 -375331.250000     -453898.500000
# 50%    1970-01-01 00:00:00.000001987  -87002.500000     -115120.500000
# 75%    1970-01-01 00:00:00.000002001   -3545.250000       -4693.750000
# max    1970-01-01 00:00:00.000002015   12404.000000        8903.000000
# std                              NaN  237806.243190      292109.320309
#
#        Balance Services  Exports Total  Exports Goods BOP  Exports Services  \
# count         56.000000   5.600000e+01       5.600000e+01         56.000000
# mean       51869.732143   6.892564e+05       4.909360e+05     198320.446429
# ...

# %% [markdown]
# Key statistics:
#
# Mean Balance Total: -187,736 (indicating an average trade deficit over time).
#
# Mean Exports Total: 689,256
#
# Mean Imports Total: 876,992

# %% [markdown]
# Trade Deficit: On average, the country has a negative balance, indicating persistent trade deficits.
#
# Exports and Imports: Both have been growing, with imports slightly outpacing exports, leading to trade deficits.

# %%
# Correlation Analysis
correlation_matrix = df.corr()
print("\nCorrelation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#                      Period  Balance Total  Balance Goods BOP  \
# Period             1.000000      -0.841873          -0.885931
# Balance Total     -0.841873       1.000000           0.985853
# Balance Goods BOP -0.885931       0.985853           1.000000
# Balance Services   0.835728      -0.715680          -0.822620
# Exports Total      0.924434      -0.871139          -0.939307
# Exports Goods BOP  0.929889      -0.875508          -0.941455
# Exports Services   0.908756      -0.858091          -0.930971
# Imports Total      0.926417      -0.926340          -0.974983
# Imports Goods BOP  0.926235      -0.929598          -0.976828
# Imports Services   0.923166      -0.905627          -0.961224
#
#                    Balance Services  Exports Total  Exports Goods BOP  \
# Period                     0.835728       0.924434           0.929889
# Balance Total             -0.715680      -0.871139          -0.875508
# ...

# %%
# Visualizing Correlation Matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# Imports and Exports have a strong positive correlation (0.99), suggesting that higher exports often coincide with higher imports.
#
# Trade balance has a strong negative correlation with imports and exports, indicating that as imports grow, the trade balance worsens.
#
# This graph tells us which variables are strongly related. Policymakers can see that controlling imports may directly improve the trade balance.

# %%
#  Distribution Analysis
plt.figure(figsize=(15, 10))
for i, col in enumerate(['Balance Total', 'Exports Total', 'Imports Total']):
    plt.subplot(3, 1, i + 1)
    sns.histplot(df[col].dropna(), bins=30, kde=True)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# The Balance Total shows a left-skewed distribution, confirming that trade deficits are more common than surpluses.
#
# Both exports and imports distributions show steady growth, with no extreme outliers.
#
# Helps to understand the distribution of trade metrics over time. The left skewness in the balance confirms the economy’s trade deficit tendencies.

# %%
# Time Series Decomposition
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(df['Balance Total'].dropna(), model='additive', period=12)
plt.figure(figsize=(12, 8))
decomposition.plot()
plt.show()

# %% [markdown]
# The Balance Total remains mostly negative over time, with some small peaks indicating trade surpluses.
#
# Both exports and imports show an upward trend, with imports growing faster than exports, leading to increasing trade deficits over time.
#
# This graph tracks the historical trends in trade. The upward trend in imports compared to exports signals areas of concern, such as over-reliance on imported goods.

# %%
# Plotting Balance Total, Exports Total, and Imports Total over Time
plt.plot(df['Period'], df['Balance Total'], label='Balance Total', color='b')
plt.plot(df['Period'], df['Exports Total'], label='Exports Total', color='g')
plt.plot(df['Period'], df['Imports Total'], label='Imports Total', color='r')

plt.title('Trends in Trade Values Over Time')
plt.xlabel('Year')
plt.ylabel('Trade Values (in millions)')
plt.legend()
plt.grid()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# The trend shows a clear downward trajectory, indicating worsening trade balances.
#
# The seasonal component shows periodic fluctuations, which may be tied to global trade cycles, holidays, or fiscal policies.
#
# By decomposing the trade balance, we can separate long-term trends from seasonal fluctuations, helping analysts to better forecast and understand trade dynamics.

# %%
# Visualizing Exports vs Imports
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Imports Total', y='Exports Total', data=df)
plt.title('Exports vs Imports')
plt.xlabel('Imports Total (in millions)')
plt.ylabel('Exports Total (in millions)')
plt.grid()
plt.show()

# %% [markdown]
# There is a clear linear relationship between exports and imports, meaning countries that export more also tend to import more.
#
# No significant outliers show extreme imbalances between exports and imports.
#
# This helps to visualize the relationship between exports and imports, confirming their close relationship. Policymakers can use this to find opportunities for trade policy adjustments.

# %%
#Box Plots for Outlier Detection
plt.figure(figsize=(15, 8))
sns.boxplot(data=df[['Balance Total', 'Exports Total', 'Imports Total']].dropna())
plt.title('Box Plots for Trade Values')
plt.ylabel('Trade Values (in millions)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Balance Total shows significant outliers, likely from extreme deficits in certain years.
#
# Exports and Imports are more stable, with fewer extreme outliers.
#
# Box plots help to detect outliers that might distort overall analysis. In this case, it’s clear that some years have experienced exceptionally high trade deficits.

# %% [markdown]
# # KEY INFERENCES

# %% [markdown]
# Persistent Trade Deficits: The country has experienced trade deficits across most of the period, driven by rising imports that outpace exports.
#
# Strong Correlation: Exports and imports have a strong positive correlation, implying the economy's global integration and dependency on foreign goods and services.
#
# Seasonality in Trade: The decomposition of trade balance data reveals cyclical patterns, which could be driven by seasonal demand or external economic conditions.
#
# Outliers: Significant outliers in the trade balance indicate periods of extreme deficit, which may correspond to global economic crises or local policy changes.
#
# Improvement Opportunities: To reduce trade deficits, the focus should be on increasing exports or reducing imports through policy measures like tariffs, trade agreements, or promoting domestic production.
